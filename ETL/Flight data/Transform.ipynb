# %%
df_c.select("DAY_OF_MONTH").orderBy(col("DAY_OF_MONTH").desc()).show(10)

# %% [markdown]
# ## Type correction

# %%
from pyspark.sql.functions import to_timestamp

# %%
combined_df = combined_df.withColumn(
    "FL_DATE",
    to_timestamp(col("FL_DATE"), "M/d/yyyy h:mm:ss a")
)
