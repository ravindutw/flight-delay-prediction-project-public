# %% [markdown]
# # Extract - Timezones

# %%
import sys
from pathlib import Path

project_root = "/notebooks/ML/Flight Delay Prediction Project/ELT"
sys.path.append(str(project_root))

# %%
from src.extract.timezones import *

# %%
df = fetch_tzs()

# %%
df.head()
# Out:
#     iata_code ident                     name   municipality  latitude_deg  \
# 204       UTK   03N           Utirik Airport  Utirik Island     11.222219
# 412       OCA  07FA  Ocean Reef Club Airport      Key Largo     25.325399
# 635       CSE  0CO2    Crested Butte Airpark  Crested Butte     38.851918
# 893       CUS  0NM0         Columbus Airport       Columbus     31.823898
# 990       JCY  0TE7        LBJ Ranch Airport      Stonewall     30.251801
#
#      longitude_deg          timezone
# 204     169.851429    Pacific/Majuro
# 412     -80.274803  America/New_York
# 635    -106.928341    America/Denver
# 893    -107.629924    America/Denver
# 990     -98.622498   America/Chicago

# %%
df.shape
# Out:
# (9056, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9056 entries, 204 to 85728
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   iata_code      9056 non-null   str
#  1   ident          9056 non-null   str
#  2   name           9056 non-null   str
#  3   municipality   8695 non-null   str
#  4   latitude_deg   9056 non-null   float64
#  5   longitude_deg  9056 non-null   float64
#  6   timezone       9056 non-null   str
# dtypes: float64(2), str(5)
# memory usage: 1.0 MB

# %% [markdown]
# ## Write data to data lake

# %%
from src.load.timezones import *

# %%
s3_key = "bronze/Flight_Delay_Prediction_Datasets/timezones/airport_timezones.parquet"
write_data_to_lake_parquet(df, s3_key)
