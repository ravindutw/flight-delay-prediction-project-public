# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
from src.utils.s3_paths import build_spark_s3_data_lake_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.utils.s3_paths import build_spark_s3_data_lake_path
#
# ModuleNotFoundError: No module named 'src'

# %%
build_spark_s3_data_lake_path("raw/Flight_Delay_Prediction_Datasets/combined_flight_data/")
# Out:
# 's3a://rwc-ml-datasets/raw/Flight_Delay_Prediction_Datasets/combined_flight_data/'

# %%
print(project_root)
# Out:
# /notebooks/ML/Flight Delay Prediction Project/ELT

# %%
from src.load.flight_data import test

# %%
test()
# Out:
# 's3a://rwc-ml-datasets/test'
