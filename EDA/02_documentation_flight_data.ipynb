# %%
import pandas as pd

# %%
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_csv("s3://rwc-ml-datasets/raw/Flight_Delay_Prediction_Datasets/flight_data/Documentation.csv")

# %%
df.head(100000)
# Out:
#            SYS_FIELD_NAME  \
# 0                    YEAR
# 1                 QUARTER
# 2                   MONTH
# 3            DAY_OF_MONTH
# 4             DAY_OF_WEEK
# 5                 FL_DATE
# 6       OP_UNIQUE_CARRIER
# 7   OP_CARRIER_AIRLINE_ID
# 8              OP_CARRIER
# 9                TAIL_NUM
# 10      ORIGIN_AIRPORT_ID
# 11  ORIGIN_AIRPORT_SEQ_ID
# 12  ORIGIN_CITY_MARKET_ID
# 13                 ORIGIN
# 14       ORIGIN_CITY_NAME
# 15       ORIGIN_STATE_ABR
# 16      ORIGIN_STATE_FIPS
# 17        ORIGIN_STATE_NM
# 18             ORIGIN_WAC
# 19        DEST_AIRPORT_ID
# 20    DEST_AIRPORT_SEQ_ID
# 21                   DEST
# 22         DEST_CITY_NAME
# 23         DEST_STATE_ABR
# 24          DEST_STATE_NM
# 25               DEST_WAC
# 26           CRS_DEP_TIME
# 27               DEP_TIME
# 28              DEP_DELAY
# 29          DEP_DELAY_NEW
# 30              DEP_DEL15
# 31        DEP_DELAY_GROUP
# 32           DEP_TIME_BLK
# 33               TAXI_OUT
# ...
